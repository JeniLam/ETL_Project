# %%
# dependencies
import pandas as pd

# %%
# pull in csv Files
moma_artists_file = "../00_raw_data_files/moma-Artists.csv"
moma_art_file = "../00_raw_data_files/moma-Artworks.csv"

# %% [markdown]
# ## Get Artists csv to only inlcude columns needed for transforming

# %%
# artists df
moma_artists = pd.read_csv(moma_artists_file)
moma_artists = pd.DataFrame(moma_artists)
list(moma_artists.columns)
# Out:
# ['ConstituentID',
#  'DisplayName',
#  'ArtistBio',
#  'Nationality',
#  'Gender',
#  'BeginDate',
#  'EndDate',
#  'Wiki QID',
#  'ULAN']

# %%
moma_artists.head()
# Out:
#    ConstituentID      DisplayName            ArtistBio Nationality Gender  \
# 0              1   Robert Arneson  American, 1930–1992    American   Male
# 1              2   Doroteo Arnaiz   Spanish, born 1936     Spanish   Male
# 2              3      Bill Arnold  American, born 1941    American   Male
# 3              4  Charles Arnoldi  American, born 1946    American   Male
# 4              5      Per Arnoldi    Danish, born 1941      Danish   Male
#
#    BeginDate  EndDate  Wiki QID         ULAN
# 0       1930     1992       NaN          NaN
# 1       1936        0       NaN          NaN
# 2       1941        0       NaN          NaN
# 3       1946        0  Q1063584  500027998.0
# 4       1941        0       NaN          NaN

# %%
# rename columns
moma_artists = moma_artists.rename(columns={'ConstituentID':'donor_id','DisplayName':'artist_name','ArtistBio':'bio'})
moma_artists.head()
# Out:
#    donor_id      artist_name                  bio Nationality Gender  \
# 0         1   Robert Arneson  American, 1930–1992    American   Male
# 1         2   Doroteo Arnaiz   Spanish, born 1936     Spanish   Male
# 2         3      Bill Arnold  American, born 1941    American   Male
# 3         4  Charles Arnoldi  American, born 1946    American   Male
# 4         5      Per Arnoldi    Danish, born 1941      Danish   Male
#
#    BeginDate  EndDate  Wiki QID         ULAN
# 0       1930     1992       NaN          NaN
# 1       1936        0       NaN          NaN
# 2       1941        0       NaN          NaN
# 3       1946        0  Q1063584  500027998.0
# 4       1941        0       NaN          NaN

# %%
moma_artists = moma_artists.rename(columns={'Nationality':'nationality','Gender':'gender','BeginDate':'birth_year','EndDate':'death_year','Wiki QID':'wiki','ULAN':'ulan'})
moma_artists.head()
# Out:
#    donor_id      artist_name                  bio nationality gender  \
# 0         1   Robert Arneson  American, 1930–1992    American   Male
# 1         2   Doroteo Arnaiz   Spanish, born 1936     Spanish   Male
# 2         3      Bill Arnold  American, born 1941    American   Male
# 3         4  Charles Arnoldi  American, born 1946    American   Male
# 4         5      Per Arnoldi    Danish, born 1941      Danish   Male
#
#    birth_year  death_year      wiki         ulan
# 0        1930        1992       NaN          NaN
# 1        1936           0       NaN          NaN
# 2        1941           0       NaN          NaN
# 3        1946           0  Q1063584  500027998.0
# 4        1941           0       NaN          NaN

# %%
# remove columns based on group decision donor_id(unique to museum), bio (repeats other columns):
moma_artists = moma_artists.drop(["donor_id", "bio"], axis =1)
moma_artists.head(2)
# Out:
#       artist_name nationality gender  birth_year  death_year wiki  ulan
# 0  Robert Arneson    American   Male        1930        1992  NaN   NaN
# 1  Doroteo Arnaiz     Spanish   Male        1936           0  NaN   NaN

# %%
# add columns necessary so all csv's have same columns
moma_artists['artist_role'] = " "
moma_artists['birth_place'] = " "
moma_artists['death_place'] = " "
moma_artists['artist_id'] = " "
moma_artists.head(2)
# Out:
#       artist_name nationality gender  birth_year  death_year wiki  ulan  \
# 0  Robert Arneson    American   Male        1930        1992  NaN   NaN
# 1  Doroteo Arnaiz     Spanish   Male        1936           0  NaN   NaN
#
#   artist_role birth_place death_place artist_id
# 0
# 1

# %%
# reorder columns so df match
moma_artists = moma_artists[['artist_id',
                            'artist_name',
                            'artist_role',
                            'nationality',
                            'gender',
                            'birth_year',
                            'birth_place',
                            'death_year',
                            'death_place',
                            'wiki',
                            'ulan']]
moma_artists.head()
# Out:
#   artist_id      artist_name artist_role nationality gender  birth_year  \
# 0             Robert Arneson                American   Male        1930
# 1             Doroteo Arnaiz                 Spanish   Male        1936
# 2                Bill Arnold                American   Male        1941
# 3            Charles Arnoldi                American   Male        1946
# 4                Per Arnoldi                  Danish   Male        1941
#
#   birth_place  death_year death_place      wiki         ulan
# 0                    1992                   NaN          NaN
# 1                       0                   NaN          NaN
# 2                       0                   NaN          NaN
# 3                       0              Q1063584  500027998.0
# 4                       0                   NaN          NaN

# %%
# export to csv
moma_artists.to_csv('../01_extracted_cleaned_data/moma_artists_transformed.csv', header=True, index=False)

# %% [markdown]
# ## Get artwork csv to only inlcude columns needed for transforming

# %%
# artwork df
moma_artwork = pd.read_csv(moma_art_file)
moma_artwork = pd.DataFrame(moma_artwork)

# %%
moma_artwork.head(2)
# Out:
#                                                Title  \
# 0  Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1  City of Music, National Superior Conservatory ...
#
#                      Artist ConstituentID              ArtistBio Nationality  \
# 0               Otto Wagner          6210  (Austrian, 1841–1918)  (Austrian)
# 1  Christian de Portzamparc          7470    (French, born 1944)    (French)
#
#   BeginDate EndDate  Gender  Date  \
# 0    (1841)  (1918)  (Male)  1896
# 1    (1944)     (0)  (Male)  1987
#
#                                           Medium  ...  \
# 0  Ink and cut-and-pasted painted pages on paper  ...
# 1              Paint and colored pencil on print  ...
#
#                                         ThumbnailURL Circumference (cm)  \
# 0  http://www.moma.org/media/W1siZiIsIjU5NDA1Il0s...                NaN
# 1  http://www.moma.org/media/W1siZiIsIjk3Il0sWyJw...                NaN
#
#   Depth (cm) Diameter (cm) Height (cm) Length (cm) Weight (kg)  Width (cm)  \
# 0        NaN           NaN     48.6000         NaN         NaN    168.9000
# 1        NaN           NaN     40.6401         NaN         NaN     29.8451
#
#   Seat Height (cm) Duration (sec.)
# 0              NaN             NaN
# 1              NaN             NaN
#
# [2 rows x 29 columns]

# %%
# Remove columns the group decided we did not need
moma_artwork = moma_artwork.drop(['ArtistBio','Nationality','BeginDate','EndDate', 'Gender', 'ObjectID','Circumference (cm)','Depth (cm)','Diameter (cm)','Weight (kg)', 'Height (cm)','Length (cm)','Seat Height (cm)','Duration (sec.)','Width (cm)','Cataloged','Dimensions'], axis = 1)
moma_artwork.head()
# Out:
#                                                Title  \
# 0  Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1  City of Music, National Superior Conservatory ...
# 2  Villa near Vienna Project, Outside Vienna, Aus...
# 3  The Manhattan Transcripts Project, New York, N...
# 4  Villa, project, outside Vienna, Austria, Exter...
#
#                      Artist ConstituentID  Date  \
# 0               Otto Wagner          6210  1896
# 1  Christian de Portzamparc          7470  1987
# 2                Emil Hoppe          7605  1903
# 3           Bernard Tschumi          7056  1980
# 4                Emil Hoppe          7605  1903
#
#                                               Medium  \
# 0      Ink and cut-and-pasted painted pages on paper
# 1                  Paint and colored pencil on print
# 2  Graphite, pen, color pencil, ink, and gouache ...
# 3  Photographic reproduction with colored synthet...
# 4  Graphite, color pencil, ink, and gouache on tr...
#
#                                           CreditLine AccessionNumber  \
# 0  Fractional and promised gift of Jo Carole and ...        885.1996
# 1  Gift of the architect in honor of Lily Auchinc...          1.1995
# 2             Gift of Jo Carole and Ronald S. Lauder          1.1997
# 3  Purchase and partial gift of the architect in ...          2.1995
# 4             Gift of Jo Carole and Ronald S. Lauder          2.1997
#
#   Classification             Department DateAcquired  \
# 0   Architecture  Architecture & Design   1996-04-09
# 1   Architecture  Architecture & Design   1995-01-17
# 2   Architecture  Architecture & Design   1997-01-15
# 3   Architecture  Architecture & Design   1995-01-17
# 4   Architecture  Architecture & Design   1997-01-15
#
#                                       URL  \
# 0  http://www.moma.org/collection/works/2
# 1  http://www.moma.org/collection/works/3
# 2  http://www.moma.org/collection/works/4
# 3  http://www.moma.org/collection/works/5
# 4  http://www.moma.org/collection/works/6
#
#                                         ThumbnailURL
# 0  http://www.moma.org/media/W1siZiIsIjU5NDA1Il0s...
# 1  http://www.moma.org/media/W1siZiIsIjk3Il0sWyJw...
# 2  http://www.moma.org/media/W1siZiIsIjk4Il0sWyJw...
# 3  http://www.moma.org/media/W1siZiIsIjEyNCJdLFsi...
# 4  http://www.moma.org/media/W1siZiIsIjEyNiJdLFsi...

# %%
list(moma_artwork.columns)
# Out:
# ['Title',
#  'Artist',
#  'ConstituentID',
#  'Date',
#  'Medium',
#  'CreditLine',
#  'AccessionNumber',
#  'Classification',
#  'Department',
#  'DateAcquired',
#  'URL',
#  'ThumbnailURL']

# %%
# rename columns in artwork df
moma_artwork = moma_artwork.rename(columns={
    'Title':'title', 
    'Artist':'artist_name',
    'ConstituentID': 'donor_id',
    'Date' : 'create_year',
    'Medium': 'medium',
    'CreditLine': 'acq',
    'AccessionNumber' : 'acc_num',
    'Classification': 'classification',
    'Department': 'dept',
    'DateAcquired': 'acq_date',
    'URL': 'web_url',
    'ThumbnailURL' : 'thumb_url'
})
moma_artwork.head()
# Out:
#                                                title  \
# 0  Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1  City of Music, National Superior Conservatory ...
# 2  Villa near Vienna Project, Outside Vienna, Aus...
# 3  The Manhattan Transcripts Project, New York, N...
# 4  Villa, project, outside Vienna, Austria, Exter...
#
#                 artist_name donor_id create_year  \
# 0               Otto Wagner     6210        1896
# 1  Christian de Portzamparc     7470        1987
# 2                Emil Hoppe     7605        1903
# 3           Bernard Tschumi     7056        1980
# 4                Emil Hoppe     7605        1903
#
#                                               medium  \
# 0      Ink and cut-and-pasted painted pages on paper
# 1                  Paint and colored pencil on print
# 2  Graphite, pen, color pencil, ink, and gouache ...
# 3  Photographic reproduction with colored synthet...
# 4  Graphite, color pencil, ink, and gouache on tr...
#
#                                                  acq   acc_num classification  \
# 0  Fractional and promised gift of Jo Carole and ...  885.1996   Architecture
# 1  Gift of the architect in honor of Lily Auchinc...    1.1995   Architecture
# 2             Gift of Jo Carole and Ronald S. Lauder    1.1997   Architecture
# 3  Purchase and partial gift of the architect in ...    2.1995   Architecture
# 4             Gift of Jo Carole and Ronald S. Lauder    2.1997   Architecture
#
#                     dept    acq_date                                 web_url  \
# 0  Architecture & Design  1996-04-09  http://www.moma.org/collection/works/2
# 1  Architecture & Design  1995-01-17  http://www.moma.org/collection/works/3
# 2  Architecture & Design  1997-01-15  http://www.moma.org/collection/works/4
# 3  Architecture & Design  1995-01-17  http://www.moma.org/collection/works/5
# 4  Architecture & Design  1997-01-15  http://www.moma.org/collection/works/6
#
#                                            thumb_url
# 0  http://www.moma.org/media/W1siZiIsIjU5NDA1Il0s...
# 1  http://www.moma.org/media/W1siZiIsIjk3Il0sWyJw...
# 2  http://www.moma.org/media/W1siZiIsIjk4Il0sWyJw...
# 3  http://www.moma.org/media/W1siZiIsIjEyNCJdLFsi...
# 4  http://www.moma.org/media/W1siZiIsIjEyNiJdLFsi...

# %%
# Add museum name
moma_artwork['museum_code'] = 2
moma_artwork['artwork_id']= ' '
moma_artwork['artist_id']= ' ' 
moma_artwork['ulan'] = ' '
moma_artwork['donor_name']= ' '
moma_artwork['donor_type']= ' '
moma_artwork.head()
# Out:
#                                                title  \
# 0  Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1  City of Music, National Superior Conservatory ...
# 2  Villa near Vienna Project, Outside Vienna, Aus...
# 3  The Manhattan Transcripts Project, New York, N...
# 4  Villa, project, outside Vienna, Austria, Exter...
#
#                 artist_name donor_id create_year  \
# 0               Otto Wagner     6210        1896
# 1  Christian de Portzamparc     7470        1987
# 2                Emil Hoppe     7605        1903
# 3           Bernard Tschumi     7056        1980
# 4                Emil Hoppe     7605        1903
#
#                                               medium  \
# 0      Ink and cut-and-pasted painted pages on paper
# 1                  Paint and colored pencil on print
# 2  Graphite, pen, color pencil, ink, and gouache ...
# 3  Photographic reproduction with colored synthet...
# 4  Graphite, color pencil, ink, and gouache on tr...
#
#                                                  acq   acc_num classification  \
# 0  Fractional and promised gift of Jo Carole and ...  885.1996   Architecture
# 1  Gift of the architect in honor of Lily Auchinc...    1.1995   Architecture
# 2             Gift of Jo Carole and Ronald S. Lauder    1.1997   Architecture
# 3  Purchase and partial gift of the architect in ...    2.1995   Architecture
# 4             Gift of Jo Carole and Ronald S. Lauder    2.1997   Architecture
#
#                     dept    acq_date                                 web_url  \
# 0  Architecture & Design  1996-04-09  http://www.moma.org/collection/works/2
# 1  Architecture & Design  1995-01-17  http://www.moma.org/collection/works/3
# 2  Architecture & Design  1997-01-15  http://www.moma.org/collection/works/4
# 3  Architecture & Design  1995-01-17  http://www.moma.org/collection/works/5
# 4  Architecture & Design  1997-01-15  http://www.moma.org/collection/works/6
#
#                                            thumb_url  museum_code artwork_id  \
# 0  http://www.moma.org/media/W1siZiIsIjU5NDA1Il0s...            2
# 1  http://www.moma.org/media/W1siZiIsIjk3Il0sWyJw...            2
# 2  http://www.moma.org/media/W1siZiIsIjk4Il0sWyJw...            2
# 3  http://www.moma.org/media/W1siZiIsIjEyNCJdLFsi...            2
# 4  http://www.moma.org/media/W1siZiIsIjEyNiJdLFsi...            2
#
#   artist_id ulan donor_name donor_type
# 0
# 1
# 2
# 3
# 4

# %%
list(moma_artwork.columns)
# Out:
# ['title',
#  'artist_name',
#  'donor_id',
#  'create_year',
#  'medium',
#  'acq',
#  'acc_num',
#  'classification',
#  'dept',
#  'acq_date',
#  'web_url',
#  'thumb_url',
#  'museum_code',
#  'artwork_id',
#  'artist_id',
#  'ulan',
#  'donor_name',
#  'donor_type']

# %%
# export to csv
moma_artwork.to_csv('../01_extracted_cleaned_data/moma_artwork_transformed.csv', header=True, index=False)
